# %%
#import necessary packages:
from bs4 import BeautifulSoup
import requests
import pandas as pd
import geocoder

# %%
with open('PostalCodesofCanada.html') as html_file:
    soup = BeautifulSoup(html_file, 'lxml')
    
match = soup.title
print(match)

data = []
table = soup.find('table', attrs={'class':'lineItemsTable'})
table_body = soup.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])
# Out:
# <title>List of postal codes of Canada: M - Wikipedia</title>

# %%
postal_codes = pd.DataFrame(data)
postal_codes.columns = ['PostalCode', 'Borough', 'Neighbourhood'] 
indexNames = postal_codes[postal_codes['Borough'] == 'Not assigned'].index
postal_codes.drop(indexNames , inplace=True)
postal_codes = postal_codes.groupby(['PostalCode', 'Borough']).Neighbourhood.agg([('Neighbourhood', ', '.join)])
postal_codes = postal_codes.reset_index()
indexes = postal_codes[postal_codes['Neighbourhood'] == 'Not assigned'].index
for i in indexes:
    postal_codes.at[i, 'Neighbourhood'] = postal_codes.at[i, 'Borough']

# %%
postal_codes.head()
# Out:
#   PostalCode      Borough                           Neighbourhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
coords = pd.read_csv('Geospatial_Coordinates.csv')
coords = coords.set_index('Postal Code')
PC = postal_codes.join(coords)
PC.head()
# Out:
#                 Borough                           Neighbourhood   Latitude  \
# PostalCode
# M1B         Scarborough                          Rouge, Malvern  43.806686
# M1C         Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# M1E         Scarborough       Guildwood, Morningside, West Hill  43.763573
# M1G         Scarborough                                  Woburn  43.770992
# M1H         Scarborough                               Cedarbrae  43.773136
#
#             Longitude
# PostalCode
# M1B        -79.194353
# M1C        -79.160497
# M1E        -79.188711
# M1G        -79.216917
# M1H        -79.239476

# %%
#I want to check the number of venues around 
with open('Venue Categories - Foursquare Developer.html') as html_file1:
    soup1 = BeautifulSoup(html_file1, 'lxml')

# %%
import scrapy

# %%
from scrapy.crawler import CrawlerProcess

class Categories(scrapy.Spider):
    name = "Categories"
    start_urls = [
        'https://developer.foursquare.com/docs/resources/categories',
    ]
    
    def parse(self, response):
        for category in response.css('div.mw-parser-output > ul > li'):
            yield {'categoryName': category.extract()}

process = CrawlerProcess()
process.crawl(Categories)
process.start()
# Out:
# 2019-06-27 23:30:32 [scrapy.utils.log] INFO: Scrapy 1.6.0 started (bot: scrapybot)
# 2019-06-27 23:30:32 [scrapy.utils.log] INFO: Versions: lxml 4.3.4.0, libxml2 2.9.9, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.2.1, Python 3.7.3 (default, Mar 27 2019, 09:23:15) - [Clang 10.0.1 (clang-1001.0.46.3)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Darwin-18.6.0-x86_64-i386-64bit
# 2019-06-27 23:30:32 [scrapy.crawler] INFO: Overridden settings: {}
# 2019-06-27 23:30:33 [scrapy.extensions.telnet] INFO: Telnet Password: 8c3a5b9f7726c6d2
# 2019-06-27 23:30:33 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2019-06-27 23:30:33 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-06-27 23:30:33 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-06-27 23:30:33 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-06-27 23:30:33 [scrapy.core.engine] INFO: Spider opened
# 2019-06-27 23:30:33 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-06-27 23:30:33 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2019-06-27 23:30:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://developer.foursquare.com/docs/resources/categories> (referer: None)
# 2019-06-27 23:30:33 [scrapy.core.engine] INFO: Closing spider (finished)
# 2019-06-27 23:30:33 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 248,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 7768,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2019, 6, 28, 4, 30, 33, 747320),
#  'log_count/DEBUG': 1,
#  'log_count/INFO': 9,
#  'memusage/max': 155807744,
#  'memusage/startup': 155807744,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2019, 6, 28, 4, 30, 33, 194073)}
# 2019-06-27 23:30:33 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
mydivs.class
# Out:
# [<div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Arte y entretenimiento</div>
#  <div class="categoryId">4d4b7104d754a06370d81259</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Anfiteatro</div>
#  <div class="categoryId">56aa371be4b08b9a8d5734db</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/aquarium_bg_32.png"/>
#  <div class="categoryName">Acuario</div>
#  <div class="categoryId">4fceea171983d5d06c3e9823</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/arcade_bg_32.png"/>
#  <div class="categoryName">Salón de Videojuegos</div>
#  <div class="categoryId">4bf58dd8d48988d1e1931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/artgallery_bg_32.png"/>
#  <div class="categoryName">Galería de arte</div>
#  <div class="categoryId">4bf58dd8d48988d1e2931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/bowling_bg_32.png"/>
#  <div class="categoryName">Bowling</div>
#  <div class="categoryId">4bf58dd8d48988d1e4931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/casino_bg_32.png"/>
#  <div class="categoryName">Casino</div>
#  <div class="categoryId">4bf58dd8d48988d17c941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Circo</div>
#  <div class="categoryId">52e81612bcbc57f1066b79e7</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/comedyclub_bg_32.png"/>
#  <div class="categoryName">Restaurante con show humorístico</div>
#  <div class="categoryId">4bf58dd8d48988d18e941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_bg_32.png"/>
#  <div class="categoryName">Sala de conciertos</div>
#  <div class="categoryId">5032792091d4c4b30a586d5c</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_dancestudio_bg_32.png"/>
#  <div class="categoryName">Club de danza folklórica</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ef</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Disco golf</div>
#  <div class="categoryId">52e81612bcbc57f1066b79e8</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Exposición</div>
#  <div class="categoryId">56aa371be4b08b9a8d573532</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Entretenimiento general</div>
#  <div class="categoryId">4bf58dd8d48988d1f1931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/racetrack_bg_32.png"/>
#  <div class="categoryName">Pista de karting</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ea</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/historicsite_bg_32.png"/>
#  <div class="categoryName">Lugar histórico</div>
#  <div class="categoryId">4deefb944765f83613cdba6e</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/karaoke_bg_32.png"/>
#  <div class="categoryName">Bar de karaoke</div>
#  <div class="categoryId">5744ccdfe4b0c0459246b4bb</div>
#  <div class="categoryCC">
#                              Supported countries:
#                                JP
#                            </div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Láser tag</div>
#  <div class="categoryId">52e81612bcbc57f1066b79e6</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/historicsite_bg_32.png"/>
#  <div class="categoryName">Monumento</div>
#  <div class="categoryId">5642206c498e4bfca532186c</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/golfcourse_bg_32.png"/>
#  <div class="categoryName">Minigolf</div>
#  <div class="categoryId">52e81612bcbc57f1066b79eb</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Cine</div>
#  <div class="categoryId">4bf58dd8d48988d17f941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Autocine</div>
#  <div class="categoryId">56aa371be4b08b9a8d5734de</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Cine independiente</div>
#  <div class="categoryId">4bf58dd8d48988d17e941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Multicine</div>
#  <div class="categoryId">4bf58dd8d48988d180941735</div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_bg_32.png"/>
#  <div class="categoryName">Museo</div>
#  <div class="categoryId">4bf58dd8d48988d181941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_art_bg_32.png"/>
#  <div class="categoryName">Museo de arte</div>
#  <div class="categoryId">4bf58dd8d48988d18f941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stripclub_bg_32.png"/>
#  <div class="categoryName">Museo del sexo</div>
#  <div class="categoryId">559acbe0498e472f1a53fa23</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_history_bg_32.png"/>
#  <div class="categoryName">Museo histórico</div>
#  <div class="categoryId">4bf58dd8d48988d190941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_planetarium_bg_32.png"/>
#  <div class="categoryName">Planetario</div>
#  <div class="categoryId">4bf58dd8d48988d192941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_science_bg_32.png"/>
#  <div class="categoryName">Museo de Ciencias</div>
#  <div class="categoryId">4bf58dd8d48988d191941735</div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_bg_32.png"/>
#  <div class="categoryName">Lugar de música</div>
#  <div class="categoryId">4bf58dd8d48988d1e5931735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_jazzclub_bg_32.png"/>
#  <div class="categoryName">Club de jazz</div>
#  <div class="categoryId">4bf58dd8d48988d1e7931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_pianobar_bg_32.png"/>
#  <div class="categoryName">Piano Bar</div>
#  <div class="categoryId">4bf58dd8d48988d1e8931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_rockclub_bg_32.png"/>
#  <div class="categoryName">Club de rock</div>
#  <div class="categoryId">4bf58dd8d48988d1e9931735</div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Sala de Pachinko</div>
#  <div class="categoryId">5744ccdfe4b0c0459246b4b8</div>
#  <div class="categoryCC">
#                              Supported countries:
#                                JP
#                            </div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_bg_32.png"/>
#  <div class="categoryName">Lugar de artes interpretativas</div>
#  <div class="categoryId">4bf58dd8d48988d1f2931735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_dancestudio_bg_32.png"/>
#  <div class="categoryName">Academia de baile</div>
#  <div class="categoryId">4bf58dd8d48988d134941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_theater_bg_32.png"/>
#  <div class="categoryName">Teatro independiente</div>
#  <div class="categoryId">4bf58dd8d48988d135941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_operahouse_bg_32.png"/>
#  <div class="categoryName">Teatro de ópera</div>
#  <div class="categoryId">4bf58dd8d48988d136941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_theater_bg_32.png"/>
#  <div class="categoryName">Teatro</div>
#  <div class="categoryId">4bf58dd8d48988d137941735</div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/billiards_bg_32.png"/>
#  <div class="categoryName">Sala de pool</div>
#  <div class="categoryId">4bf58dd8d48988d1e3931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Arte público</div>
#  <div class="categoryId">507c8c4091d498d9fc8c67a9</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/sculpture_bg_32.png"/>
#  <div class="categoryName">Escultura al aire libre</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ed</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Arte callejero</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ee</div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_track_bg_32.png"/>
#  <div class="categoryName">Hipódromo</div>
#  <div class="categoryId">56aa371be4b08b9a8d573514</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/racetrack_bg_32.png"/>
#  <div class="categoryName">Circuito</div>
#  <div class="categoryId">4bf58dd8d48988d1f4931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Pista de patinaje sobre ruedas</div>
#  <div class="categoryId">52e81612bcbc57f1066b79e9</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_dancestudio_bg_32.png"/>
#  <div class="categoryName">Club de salsa</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ec</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_dancestudio_bg_32.png"/>
#  <div class="categoryName">Escuela de Samba</div>
#  <div class="categoryId">56aa371be4b08b9a8d5734f9</div>
#  <div class="categoryCC">
#                              Supported countries:
#                                BR
#                            </div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_bg_32.png"/>
#  <div class="categoryName">Estadio</div>
#  <div class="categoryId">4bf58dd8d48988d184941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_baseball_bg_32.png"/>
#  <div class="categoryName">Estadio de béisbol</div>
#  <div class="categoryId">4bf58dd8d48988d18c941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_basketball_bg_32.png"/>
#  <div class="categoryName">Estadio de baloncesto</div>
#  <div class="categoryId">4bf58dd8d48988d18b941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_cricket_bg_32.png"/>
#  <div class="categoryName">Cancha de críquet</div>
#  <div class="categoryId">4bf58dd8d48988d18a941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_football_bg_32.png"/>
#  <div class="categoryName">Estadio de fútbol</div>
#  <div class="categoryId">4bf58dd8d48988d189941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_hockey_bg_32.png"/>
#  <div class="categoryName">Estadio de hockey</div>
#  <div class="categoryId">4bf58dd8d48988d185941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_football_bg_32.png"/>
#  <div class="categoryName">Estadio de rugby</div>
#  <div class="categoryId">56aa371be4b08b9a8d573556</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_soccer_bg_32.png"/>
#  <div class="categoryName">Estadio de fútbol</div>
#  <div class="categoryId">4bf58dd8d48988d188941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_tennis_bg_32.png"/>
#  <div class="categoryName">Estadio de tenis</div>
#  <div class="categoryId">4e39a891bd410d7aed40cbc2</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_track_bg_32.png"/>
#  <div class="categoryName">Estadio de atletismo</div>
#  <div class="categoryId">4bf58dd8d48988d187941735</div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/themepark_bg_32.png"/>
#  <div class="categoryName">Parque temático</div>
#  <div class="categoryId">4bf58dd8d48988d182941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/themepark_bg_32.png"/>
#  <div class="categoryName">Juego/atracción en parque temático</div>
#  <div class="categoryId">5109983191d435c0d71c2bb1</div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Facilitador del tour</div>
#  <div class="categoryId">56aa371be4b08b9a8d573520</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/waterpark_bg_32.png"/>
#  <div class="categoryName">Parque de agua</div>
#  <div class="categoryId">4bf58dd8d48988d193941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/zoo_bg_32.png"/>
#  <div class="categoryName">Zoológico</div>
#  <div class="categoryId">4bf58dd8d48988d17b941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/zoo_bg_32.png"/>
#  <div class="categoryName">Exhibición en zoológico</div>
#  <div class="categoryId">58daa1558bbb0b01f18ec1fd</div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Anfiteatro</div>
#  <div class="categoryId">56aa371be4b08b9a8d5734db</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/aquarium_bg_32.png"/>
#  <div class="categoryName">Acuario</div>
#  <div class="categoryId">4fceea171983d5d06c3e9823</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/arcade_bg_32.png"/>
#  <div class="categoryName">Salón de Videojuegos</div>
#  <div class="categoryId">4bf58dd8d48988d1e1931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/artgallery_bg_32.png"/>
#  <div class="categoryName">Galería de arte</div>
#  <div class="categoryId">4bf58dd8d48988d1e2931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/bowling_bg_32.png"/>
#  <div class="categoryName">Bowling</div>
#  <div class="categoryId">4bf58dd8d48988d1e4931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/casino_bg_32.png"/>
#  <div class="categoryName">Casino</div>
#  <div class="categoryId">4bf58dd8d48988d17c941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Circo</div>
#  <div class="categoryId">52e81612bcbc57f1066b79e7</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/comedyclub_bg_32.png"/>
#  <div class="categoryName">Restaurante con show humorístico</div>
#  <div class="categoryId">4bf58dd8d48988d18e941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_bg_32.png"/>
#  <div class="categoryName">Sala de conciertos</div>
#  <div class="categoryId">5032792091d4c4b30a586d5c</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_dancestudio_bg_32.png"/>
#  <div class="categoryName">Club de danza folklórica</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ef</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Disco golf</div>
#  <div class="categoryId">52e81612bcbc57f1066b79e8</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Exposición</div>
#  <div class="categoryId">56aa371be4b08b9a8d573532</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Entretenimiento general</div>
#  <div class="categoryId">4bf58dd8d48988d1f1931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/racetrack_bg_32.png"/>
#  <div class="categoryName">Pista de karting</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ea</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/historicsite_bg_32.png"/>
#  <div class="categoryName">Lugar histórico</div>
#  <div class="categoryId">4deefb944765f83613cdba6e</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/karaoke_bg_32.png"/>
#  <div class="categoryName">Bar de karaoke</div>
#  <div class="categoryId">5744ccdfe4b0c0459246b4bb</div>
#  <div class="categoryCC">
#                              Supported countries:
#                                JP
#                            </div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Láser tag</div>
#  <div class="categoryId">52e81612bcbc57f1066b79e6</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/historicsite_bg_32.png"/>
#  <div class="categoryName">Monumento</div>
#  <div class="categoryId">5642206c498e4bfca532186c</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/golfcourse_bg_32.png"/>
#  <div class="categoryName">Minigolf</div>
#  <div class="categoryId">52e81612bcbc57f1066b79eb</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Cine</div>
#  <div class="categoryId">4bf58dd8d48988d17f941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Autocine</div>
#  <div class="categoryId">56aa371be4b08b9a8d5734de</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Cine independiente</div>
#  <div class="categoryId">4bf58dd8d48988d17e941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Multicine</div>
#  <div class="categoryId">4bf58dd8d48988d180941735</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Autocine</div>
#  <div class="categoryId">56aa371be4b08b9a8d5734de</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Cine independiente</div>
#  <div class="categoryId">4bf58dd8d48988d17e941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movietheater_bg_32.png"/>
#  <div class="categoryName">Multicine</div>
#  <div class="categoryId">4bf58dd8d48988d180941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_bg_32.png"/>
#  <div class="categoryName">Museo</div>
#  <div class="categoryId">4bf58dd8d48988d181941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_art_bg_32.png"/>
#  <div class="categoryName">Museo de arte</div>
#  <div class="categoryId">4bf58dd8d48988d18f941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stripclub_bg_32.png"/>
#  <div class="categoryName">Museo del sexo</div>
#  <div class="categoryId">559acbe0498e472f1a53fa23</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_history_bg_32.png"/>
#  <div class="categoryName">Museo histórico</div>
#  <div class="categoryId">4bf58dd8d48988d190941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_planetarium_bg_32.png"/>
#  <div class="categoryName">Planetario</div>
#  <div class="categoryId">4bf58dd8d48988d192941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_science_bg_32.png"/>
#  <div class="categoryName">Museo de Ciencias</div>
#  <div class="categoryId">4bf58dd8d48988d191941735</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_art_bg_32.png"/>
#  <div class="categoryName">Museo de arte</div>
#  <div class="categoryId">4bf58dd8d48988d18f941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stripclub_bg_32.png"/>
#  <div class="categoryName">Museo del sexo</div>
#  <div class="categoryId">559acbe0498e472f1a53fa23</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_history_bg_32.png"/>
#  <div class="categoryName">Museo histórico</div>
#  <div class="categoryId">4bf58dd8d48988d190941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_planetarium_bg_32.png"/>
#  <div class="categoryName">Planetario</div>
#  <div class="categoryId">4bf58dd8d48988d192941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/museum_science_bg_32.png"/>
#  <div class="categoryName">Museo de Ciencias</div>
#  <div class="categoryId">4bf58dd8d48988d191941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_bg_32.png"/>
#  <div class="categoryName">Lugar de música</div>
#  <div class="categoryId">4bf58dd8d48988d1e5931735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_jazzclub_bg_32.png"/>
#  <div class="categoryName">Club de jazz</div>
#  <div class="categoryId">4bf58dd8d48988d1e7931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_pianobar_bg_32.png"/>
#  <div class="categoryName">Piano Bar</div>
#  <div class="categoryId">4bf58dd8d48988d1e8931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_rockclub_bg_32.png"/>
#  <div class="categoryName">Club de rock</div>
#  <div class="categoryId">4bf58dd8d48988d1e9931735</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_jazzclub_bg_32.png"/>
#  <div class="categoryName">Club de jazz</div>
#  <div class="categoryId">4bf58dd8d48988d1e7931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_pianobar_bg_32.png"/>
#  <div class="categoryName">Piano Bar</div>
#  <div class="categoryId">4bf58dd8d48988d1e8931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/musicvenue_rockclub_bg_32.png"/>
#  <div class="categoryName">Club de rock</div>
#  <div class="categoryId">4bf58dd8d48988d1e9931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Sala de Pachinko</div>
#  <div class="categoryId">5744ccdfe4b0c0459246b4b8</div>
#  <div class="categoryCC">
#                              Supported countries:
#                                JP
#                            </div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_bg_32.png"/>
#  <div class="categoryName">Lugar de artes interpretativas</div>
#  <div class="categoryId">4bf58dd8d48988d1f2931735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_dancestudio_bg_32.png"/>
#  <div class="categoryName">Academia de baile</div>
#  <div class="categoryId">4bf58dd8d48988d134941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_theater_bg_32.png"/>
#  <div class="categoryName">Teatro independiente</div>
#  <div class="categoryId">4bf58dd8d48988d135941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_operahouse_bg_32.png"/>
#  <div class="categoryName">Teatro de ópera</div>
#  <div class="categoryId">4bf58dd8d48988d136941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_theater_bg_32.png"/>
#  <div class="categoryName">Teatro</div>
#  <div class="categoryId">4bf58dd8d48988d137941735</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_dancestudio_bg_32.png"/>
#  <div class="categoryName">Academia de baile</div>
#  <div class="categoryId">4bf58dd8d48988d134941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_theater_bg_32.png"/>
#  <div class="categoryName">Teatro independiente</div>
#  <div class="categoryId">4bf58dd8d48988d135941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_operahouse_bg_32.png"/>
#  <div class="categoryName">Teatro de ópera</div>
#  <div class="categoryId">4bf58dd8d48988d136941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_theater_bg_32.png"/>
#  <div class="categoryName">Teatro</div>
#  <div class="categoryId">4bf58dd8d48988d137941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/billiards_bg_32.png"/>
#  <div class="categoryName">Sala de pool</div>
#  <div class="categoryId">4bf58dd8d48988d1e3931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Arte público</div>
#  <div class="categoryId">507c8c4091d498d9fc8c67a9</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/sculpture_bg_32.png"/>
#  <div class="categoryName">Escultura al aire libre</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ed</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Arte callejero</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ee</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/sculpture_bg_32.png"/>
#  <div class="categoryName">Escultura al aire libre</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ed</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Arte callejero</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ee</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_track_bg_32.png"/>
#  <div class="categoryName">Hipódromo</div>
#  <div class="categoryId">56aa371be4b08b9a8d573514</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/racetrack_bg_32.png"/>
#  <div class="categoryName">Circuito</div>
#  <div class="categoryId">4bf58dd8d48988d1f4931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Pista de patinaje sobre ruedas</div>
#  <div class="categoryId">52e81612bcbc57f1066b79e9</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_dancestudio_bg_32.png"/>
#  <div class="categoryName">Club de salsa</div>
#  <div class="categoryId">52e81612bcbc57f1066b79ec</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/performingarts_dancestudio_bg_32.png"/>
#  <div class="categoryName">Escuela de Samba</div>
#  <div class="categoryId">56aa371be4b08b9a8d5734f9</div>
#  <div class="categoryCC">
#                              Supported countries:
#                                BR
#                            </div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_bg_32.png"/>
#  <div class="categoryName">Estadio</div>
#  <div class="categoryId">4bf58dd8d48988d184941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_baseball_bg_32.png"/>
#  <div class="categoryName">Estadio de béisbol</div>
#  <div class="categoryId">4bf58dd8d48988d18c941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_basketball_bg_32.png"/>
#  <div class="categoryName">Estadio de baloncesto</div>
#  <div class="categoryId">4bf58dd8d48988d18b941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_cricket_bg_32.png"/>
#  <div class="categoryName">Cancha de críquet</div>
#  <div class="categoryId">4bf58dd8d48988d18a941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_football_bg_32.png"/>
#  <div class="categoryName">Estadio de fútbol</div>
#  <div class="categoryId">4bf58dd8d48988d189941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_hockey_bg_32.png"/>
#  <div class="categoryName">Estadio de hockey</div>
#  <div class="categoryId">4bf58dd8d48988d185941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_football_bg_32.png"/>
#  <div class="categoryName">Estadio de rugby</div>
#  <div class="categoryId">56aa371be4b08b9a8d573556</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_soccer_bg_32.png"/>
#  <div class="categoryName">Estadio de fútbol</div>
#  <div class="categoryId">4bf58dd8d48988d188941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_tennis_bg_32.png"/>
#  <div class="categoryName">Estadio de tenis</div>
#  <div class="categoryId">4e39a891bd410d7aed40cbc2</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_track_bg_32.png"/>
#  <div class="categoryName">Estadio de atletismo</div>
#  <div class="categoryId">4bf58dd8d48988d187941735</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_baseball_bg_32.png"/>
#  <div class="categoryName">Estadio de béisbol</div>
#  <div class="categoryId">4bf58dd8d48988d18c941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_basketball_bg_32.png"/>
#  <div class="categoryName">Estadio de baloncesto</div>
#  <div class="categoryId">4bf58dd8d48988d18b941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_cricket_bg_32.png"/>
#  <div class="categoryName">Cancha de críquet</div>
#  <div class="categoryId">4bf58dd8d48988d18a941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_football_bg_32.png"/>
#  <div class="categoryName">Estadio de fútbol</div>
#  <div class="categoryId">4bf58dd8d48988d189941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_hockey_bg_32.png"/>
#  <div class="categoryName">Estadio de hockey</div>
#  <div class="categoryId">4bf58dd8d48988d185941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_football_bg_32.png"/>
#  <div class="categoryName">Estadio de rugby</div>
#  <div class="categoryId">56aa371be4b08b9a8d573556</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_soccer_bg_32.png"/>
#  <div class="categoryName">Estadio de fútbol</div>
#  <div class="categoryId">4bf58dd8d48988d188941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_tennis_bg_32.png"/>
#  <div class="categoryName">Estadio de tenis</div>
#  <div class="categoryId">4e39a891bd410d7aed40cbc2</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_track_bg_32.png"/>
#  <div class="categoryName">Estadio de atletismo</div>
#  <div class="categoryId">4bf58dd8d48988d187941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/themepark_bg_32.png"/>
#  <div class="categoryName">Parque temático</div>
#  <div class="categoryId">4bf58dd8d48988d182941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/themepark_bg_32.png"/>
#  <div class="categoryName">Juego/atracción en parque temático</div>
#  <div class="categoryId">5109983191d435c0d71c2bb1</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/themepark_bg_32.png"/>
#  <div class="categoryName">Juego/atracción en parque temático</div>
#  <div class="categoryId">5109983191d435c0d71c2bb1</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Facilitador del tour</div>
#  <div class="categoryId">56aa371be4b08b9a8d573520</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/waterpark_bg_32.png"/>
#  <div class="categoryName">Parque de agua</div>
#  <div class="categoryId">4bf58dd8d48988d193941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/zoo_bg_32.png"/>
#  <div class="categoryName">Zoológico</div>
#  <div class="categoryId">4bf58dd8d48988d17b941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/zoo_bg_32.png"/>
#  <div class="categoryName">Exhibición en zoológico</div>
#  <div class="categoryId">58daa1558bbb0b01f18ec1fd</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/zoo_bg_32.png"/>
#  <div class="categoryName">Exhibición en zoológico</div>
#  <div class="categoryId">58daa1558bbb0b01f18ec1fd</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(1).png"/>
#  <div class="categoryName">Facultad y Universidad</div>
#  <div class="categoryId">4d4b7105d754a06372d81259</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/academicbuilding_bg_32.png"/>
#  <div class="categoryName">Edificio universitario académico</div>
#  <div class="categoryId">4bf58dd8d48988d198941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32.png"/>
#  <div class="categoryName">Edificio universitario de Filosofía y Letras</div>
#  <div class="categoryId">4bf58dd8d48988d199941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/collegeacademicbuildings_communications_bg_32.png"/>
#  <div class="categoryName">Edificio universitario de comunicaciones</div>
#  <div class="categoryId">4bf58dd8d48988d19a941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/collegeacademicbuildings_engineering_bg_32.png"/>
#  <div class="categoryName">Edificio universitario de ingeniería</div>
#  <div class="categoryId">4bf58dd8d48988d19e941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/collegeacademicbuildings_history_bg_32.png"/>
#  <div class="categoryName">Edificio universitario de Historia</div>
#  <div class="categoryId">4bf58dd8d48988d19d941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/collegeacademicbuildings_math_bg_32.png"/>
#  <div class="categoryName">Edificio universitario de Matemáticas</div>
#  <div class="categoryId">4bf58dd8d48988d19c941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/collegeacademicbuildings_science_bg_32.png"/>
#  <div class="categoryName">Edificio universitario de Ciencias</div>
#  <div class="categoryId">4bf58dd8d48988d19b941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/collegeacademicbuildings_technology_bg_32.png"/>
#  <div class="categoryName">Edificio universitario de Tecnología</div>
#  <div class="categoryId">4bf58dd8d48988d19f941735</div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/administrativebuilding_bg_32.png"/>
#  <div class="categoryName">Edificio universitario administrativo</div>
#  <div class="categoryId">4bf58dd8d48988d197941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/auditorium_bg_32.png"/>
#  <div class="categoryName">Auditorio universitario</div>
#  <div class="categoryId">4bf58dd8d48988d1af941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/bookstore_bg_32.png"/>
#  <div class="categoryName">Librería universitaria</div>
#  <div class="categoryId">4bf58dd8d48988d1b1941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/cafeteria_bg_32.png"/>
#  <div class="categoryName">Cafetería universitaria</div>
#  <div class="categoryId">4bf58dd8d48988d1a1941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/classroom_bg_32.png"/>
#  <div class="categoryName">Aula universitaria</div>
#  <div class="categoryId">4bf58dd8d48988d1a0941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/gym_bg_32.png"/>
#  <div class="categoryName">Gimnasio universitario</div>
#  <div class="categoryId">4bf58dd8d48988d1b2941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/lab_bg_32.png"/>
#  <div class="categoryName">Laboratorio universitario</div>
#  <div class="categoryId">4bf58dd8d48988d1a5941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/library_bg_32.png"/>
#  <div class="categoryName">Biblioteca universitaria</div>
#  <div class="categoryId">4bf58dd8d48988d1a7941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/quad_bg_32.png"/>
#  <div class="categoryName">Patio interior universitario</div>
#  <div class="categoryId">4bf58dd8d48988d1aa941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/reccenter_bg_32.png"/>
#  <div class="categoryName">Centro recreativo universitario</div>
#  <div class="categoryId">4bf58dd8d48988d1a9941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/residencehall_bg_32.png"/>
#  <div class="categoryName">Residencia universitaria de estudiantes</div>
#  <div class="categoryId">4bf58dd8d48988d1a3941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_bg_32.png"/>
#  <div class="categoryName">Estadio universitario</div>
#  <div class="categoryId">4bf58dd8d48988d1b4941735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_baseball_bg_32.png"/>
#  <div class="categoryName">Diamante universitario de béisbol</div>
#  <div class="categoryId">4bf58dd8d48988d1bb941735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/stadium_basketball_bg_32.png"/>
#  <div class="categoryName">Cancha universitaria de baloncesto</div>
# ...
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/airport_bg_32.png"/>
#  <div class="categoryName">Avión</div>
#  <div class="categoryId">4bf58dd8d48988d1f7931735</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/airport_bg_32.png"/>
#  <div class="categoryName">Plaza de comidas del aeropuerto</div>
#  <div class="categoryId">4bf58dd8d48988d1ef931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/airport_gate_bg_32.png"/>
#  <div class="categoryName">Puerta de embarque del aeropuerto</div>
#  <div class="categoryId">4bf58dd8d48988d1f0931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(5).png"/>
#  <div class="categoryName">Sala del aeropuerto</div>
#  <div class="categoryId">4eb1bc533b7b2c5b1d4306cb</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/airport_bg_32.png"/>
#  <div class="categoryName">Servicio de aeropuerto</div>
#  <div class="categoryId">56aa371be4b08b9a8d57352f</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/airport_gate_bg_32.png"/>
#  <div class="categoryName">Terminal del aeropuerto</div>
#  <div class="categoryId">4bf58dd8d48988d1eb931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/airport_tram_bg_32.png"/>
#  <div class="categoryName">Tranvía del aeropuerto</div>
#  <div class="categoryId">4bf58dd8d48988d1ec931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(8).png"/>
#  <div class="categoryName">Área de reclamo de equipaje</div>
#  <div class="categoryId">5744ccdfe4b0c0459246b4e5</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/airport_bg_32.png"/>
#  <div class="categoryName">Avión</div>
#  <div class="categoryId">4bf58dd8d48988d1f7931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(8).png"/>
#  <div class="categoryName">Área de almacenamiento de equipaje</div>
#  <div class="categoryId">5744ccdfe4b0c0459246b4e8</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/bikeshop_bg_32.png"/>
#  <div class="categoryName">Alquiler de bicicletas/Bicicletas públicas</div>
#  <div class="categoryId">4e4c9077bd41f78e849722f9</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/boat_bg_32.png"/>
#  <div class="categoryName">Agencia de alquiler de botes</div>
#  <div class="categoryId">5744ccdfe4b0c0459246b4c1</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/boat_bg_32.png"/>
#  <div class="categoryName">Barco o ferry</div>
#  <div class="categoryId">4bf58dd8d48988d12d951735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(8).png"/>
#  <div class="categoryName">Paso fronterizo</div>
#  <div class="categoryId">52f2ab2ebcbc57f1066b8b4b</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/busstation_bg_32.png"/>
#  <div class="categoryName">Estación de autobuses</div>
#  <div class="categoryId">4bf58dd8d48988d1fe931735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/busstation_bg_32.png"/>
#  <div class="categoryName">Línea de autobús</div>
#  <div class="categoryId">4bf58dd8d48988d12b951735</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/busstation_bg_32.png"/>
#  <div class="categoryName">Línea de autobús</div>
#  <div class="categoryId">4bf58dd8d48988d12b951735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/busstation_bg_32.png"/>
#  <div class="categoryName">Parada de autobuses</div>
#  <div class="categoryId">52f2ab2ebcbc57f1066b8b4f</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/trainstation_bg_32.png"/>
#  <div class="categoryName">Teleférico</div>
#  <div class="categoryId">52f2ab2ebcbc57f1066b8b50</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/boat_bg_32.png"/>
#  <div class="categoryName">Crucero</div>
#  <div class="categoryId">55077a22498e5e9248869ba2</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(3).png"/>
#  <div class="categoryName">Tienda libre de impuestos</div>
#  <div class="categoryId">589ddde98ae3635c072819ee</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(8).png"/>
#  <div class="categoryName">Viajes en general</div>
#  <div class="categoryId">4bf58dd8d48988d1f6931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(8).png"/>
#  <div class="categoryName">Helipuerto</div>
#  <div class="categoryId">56aa371ce4b08b9a8d57356e</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hotel_bg_32.png"/>
#  <div class="categoryName">Hotel</div>
#  <div class="categoryId">4bf58dd8d48988d1fa931735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/bedandbreakfast_bg_32.png"/>
#  <div class="categoryName">Alojamiento y desayuno</div>
#  <div class="categoryId">4bf58dd8d48988d1f8931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hotel_bg_32.png"/>
#  <div class="categoryName">Pensión</div>
#  <div class="categoryId">4f4530a74b9074f6e4fb0100</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hostel_bg_32.png"/>
#  <div class="categoryName">Albergue juvenil</div>
#  <div class="categoryId">4bf58dd8d48988d1ee931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/pool_bg_32.png"/>
#  <div class="categoryName">Piscina del hotel</div>
#  <div class="categoryId">4bf58dd8d48988d132951735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hotel_bg_32.png"/>
#  <div class="categoryName">Inn</div>
#  <div class="categoryId">5bae9231bedf3950379f89cb</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hotel_bg_32.png"/>
#  <div class="categoryName">Motel</div>
#  <div class="categoryId">4bf58dd8d48988d1fb931735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/resort_bg_32.png"/>
#  <div class="categoryName">Centro turístico</div>
#  <div class="categoryId">4bf58dd8d48988d12f951735</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hostel_bg_32.png"/>
#  <div class="categoryName">Alquiler de vacaciones</div>
#  <div class="categoryId">56aa371be4b08b9a8d5734e1</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/bedandbreakfast_bg_32.png"/>
#  <div class="categoryName">Alojamiento y desayuno</div>
#  <div class="categoryId">4bf58dd8d48988d1f8931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hotel_bg_32.png"/>
#  <div class="categoryName">Pensión</div>
#  <div class="categoryId">4f4530a74b9074f6e4fb0100</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hostel_bg_32.png"/>
#  <div class="categoryName">Albergue juvenil</div>
#  <div class="categoryId">4bf58dd8d48988d1ee931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/pool_bg_32.png"/>
#  <div class="categoryName">Piscina del hotel</div>
#  <div class="categoryId">4bf58dd8d48988d132951735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hotel_bg_32.png"/>
#  <div class="categoryName">Inn</div>
#  <div class="categoryId">5bae9231bedf3950379f89cb</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hotel_bg_32.png"/>
#  <div class="categoryName">Motel</div>
#  <div class="categoryId">4bf58dd8d48988d1fb931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/resort_bg_32.png"/>
#  <div class="categoryName">Centro turístico</div>
#  <div class="categoryId">4bf58dd8d48988d12f951735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/hostel_bg_32.png"/>
#  <div class="categoryName">Alquiler de vacaciones</div>
#  <div class="categoryId">56aa371be4b08b9a8d5734e1</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(8).png"/>
#  <div class="categoryName">Intersección</div>
#  <div class="categoryId">52f2ab2ebcbc57f1066b8b4c</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/lightrail_bg_32.png"/>
#  <div class="categoryName">Estación de tren ligero</div>
#  <div class="categoryId">4bf58dd8d48988d1fc931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/subway_bg_32.png"/>
#  <div class="categoryName">Estación de metro</div>
#  <div class="categoryId">4bf58dd8d48988d1fd931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/movingtarget_bg_32.png"/>
#  <div class="categoryName">Objetivo en movimiento</div>
#  <div class="categoryId">4f2a23984b9023bd5841ed2c</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/ferry_pier_bg_32.png"/>
#  <div class="categoryName">Muelle</div>
#  <div class="categoryId">4e74f6cabd41c4836eac4c31</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/boat_bg_32.png"/>
#  <div class="categoryName">Puerto</div>
#  <div class="categoryId">56aa371be4b08b9a8d57353e</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(6).png"/>
#  <div class="categoryName">Parque para vehículos recreacionales (RV)</div>
#  <div class="categoryId">52f2ab2ebcbc57f1066b8b53</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/airport_rentalcar_bg_32.png"/>
#  <div class="categoryName">Local de alquiler de coches</div>
#  <div class="categoryId">4bf58dd8d48988d1ef941735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/restarea_bg_32.png"/>
#  <div class="categoryName">Área de reposo</div>
#  <div class="categoryId">4d954b16a243a5684b65b473</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/highway_bg_32.png"/>
#  <div class="categoryName">Carretera</div>
#  <div class="categoryId">4bf58dd8d48988d1f9931735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/taxi_bg_32.png"/>
#  <div class="categoryName">Parada de taxi</div>
#  <div class="categoryId">53fca564498e1a175f32528b</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/taxi_bg_32.png"/>
#  <div class="categoryName">Taxi</div>
#  <div class="categoryId">4bf58dd8d48988d130951735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(8).png"/>
#  <div class="categoryName">Cabina de peaje</div>
#  <div class="categoryId">52f2ab2ebcbc57f1066b8b4d</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(8).png"/>
#  <div class="categoryName">Plaza de peaje</div>
#  <div class="categoryId">52f2ab2ebcbc57f1066b8b4e</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/touristinformation_bg_32.png"/>
#  <div class="categoryName">Centro de Información Turística</div>
#  <div class="categoryId">4f4530164b9074f6e4fb00ff</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/trainstation_bg_32.png"/>
#  <div class="categoryName">Estación de tren</div>
#  <div class="categoryId">4bf58dd8d48988d129951735</div>
#  <ul class="categoryChildren">
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/trainstation_bg_32.png"/>
#  <div class="categoryName">Plataforma</div>
#  <div class="categoryId">4f4531504b9074f6e4fb0102</div>
#  </div>
#  </li>
#  <li>
#  <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/trainstation_bg_32.png"/>
#  <div class="categoryName">Tren</div>
#  <div class="categoryId">4bf58dd8d48988d12a951735</div>
#  </div>
#  </li>
#  </ul>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/trainstation_bg_32.png"/>
#  <div class="categoryName">Plataforma</div>
#  <div class="categoryId">4f4531504b9074f6e4fb0102</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/trainstation_bg_32.png"/>
#  <div class="categoryName">Tren</div>
#  <div class="categoryId">4bf58dd8d48988d12a951735</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/trainstation_bg_32.png"/>
#  <div class="categoryName">Estación de tranvía</div>
#  <div class="categoryId">52f2ab2ebcbc57f1066b8b51</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/taxi_bg_32.png"/>
#  <div class="categoryName">Servicio de transporte</div>
#  <div class="categoryId">54541b70498ea6ccd0204bff</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(5).png"/>
#  <div class="categoryName">Sala de viaje</div>
#  <div class="categoryId">4f04b25d2fb6e1c99f3db0c0</div>
#  </div>, <div class="categoryItem">
#  <img class="categoryIcon" src="./Venue Categories - Foursquare Developer_files/default_bg_32(8).png"/>
#  <div class="categoryName">Túnel</div>
#  <div class="categoryId">52f2ab2ebcbc57f1066b8b4a</div>
#  </div>]

# %%
print(mydivs2)
# Out:
# None
